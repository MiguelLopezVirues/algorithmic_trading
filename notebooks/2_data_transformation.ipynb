# %% [markdown]
# # Data transformation

# %% [markdown]
# # 1. Introduction and purpose

# %% [markdown]
# This notebook has the purpose of transformating/cleaning the data obtained in the extraction step from `notebooks/1.data_extraction.ipynb`.
#
# Transformation goals are:
# - Cleaning and formatting of tables extracted
# - Generation of Technical Indicators from OHLCV data

# %% [markdown]
# TO-DO:
# - [] Modify/clean technical indicators function
# - [] Add ffil for macroindicators when missing with respect to other markets due to non-working days (as opposed to not yet reported), as of "last price".
# - [] Inthe case of BTC, as we are predicting stocks, exclude non coincidental days.
# - [] Save all transformed files. Explore cloud sources to host the data.

# %% [markdown]
# # 2. Data transformation

# %%
# %load_ext autoreload
# %autoreload 2

# Data preparation
import numpy as np
import polars as pl
import pandas as pd

# Data
import sys
sys.path.append("..")

from src.support.data_transformation import TickerExtender, TechnicalIndicators, FileHandler

# %% [markdown]
# # 1. OHLCV

# %% [markdown]
# ## 1.1 Adding simple temporal growth and simple technical indicators

# %%
ticker_extender = TickerExtender()

stocks_df_list = ticker_extender.transform_daily_tickers_parallel("../../data/extracted/OHLCV")

# %% [markdown]
# ## 1.2 Adding Technical Indicators

# %%
print("Enriching ticker dataframes.")
ticker_df_list = ticker_extender.transform_daily_tickers_parallel("../../data/extracted/OHLCV")
print("Merging into one collection.")
merged_df_with_tech_ind = ticker_extender.merge_tickers(ticker_df_list)

merged_df_with_tech_ind
# Out:
# Enriching ticker dataframes.
# Merging into one collection.
# shape: (227_098, 149)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ datetime  ┆ close     ┆ high      ┆ low       ┆ … ┆ cdltrista ┆ cdlunique ┆ cdlupside ┆ cdlxside │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ r         ┆ 3river    ┆ gap2crows ┆ gap3meth │
# │ datetime[ ┆ f64       ┆ f64       ┆ f64       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ods      │
# │ ns]       ┆           ┆           ┆           ┆   ┆ i32       ┆ i32       ┆ i32       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ i32      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 2009-08-0 ┆ 1.150074  ┆ 1.201963  ┆ 1.106005  ┆ … ┆ 0         ┆ 0         ┆ 0         ┆ 0        │
# │ 6         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2009-08-0 ┆ 1.167844  ┆ 1.191301  ┆ 1.139412  ┆ … ┆ 0         ┆ 0         ┆ 0         ┆ 0        │
# │ 7         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2009-08-1 ┆ 1.135147  ┆ 1.18206   ┆ 1.109558  ┆ … ┆ 0         ┆ 0         ┆ 0         ┆ 0        │
# │ 0         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2009-08-1 ┆ 1.113823  ┆ 1.13728   ┆ 1.10174   ┆ … ┆ 0         ┆ 0         ┆ 0         ┆ 0        │
# │ 1         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2009-08-1 ┆ 1.13728   ┆ 1.151495  ┆ 1.113112  ┆ … ┆ 0         ┆ 0         ┆ 0         ┆ 0        │
# │ 2         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ 2025-01-1 ┆ 59.490002 ┆ 59.639999 ┆ 58.970001 ┆ … ┆ 0         ┆ 0         ┆ 0         ┆ 0        │
# │ 7         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2025-01-2 ┆ 59.110001 ┆ 59.459999 ┆ 58.740002 ┆ … ┆ 0         ┆ 0         ┆ 0         ┆ 0        │
# │ 1         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2025-01-2 ┆ 58.110001 ┆ 58.790001 ┆ 58.080002 ┆ … ┆ 0         ┆ 0         ┆ 0         ┆ 0        │
# │ 2         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2025-01-2 ┆ 58.75     ┆ 59.02     ┆ 58.25     ┆ … ┆ 0         ┆ 0         ┆ 0         ┆ 0        │
# │ 3         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2025-01-2 ┆ 58.73     ┆ 59.060001 ┆ 58.459999 ┆ … ┆ 0         ┆ 0         ┆ 0         ┆ 0        │
# │ 4         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
merged_df_with_tech_ind[["datetime","symbol"]]
# Out:
# shape: (227_098, 2)
# ┌─────────────────────┬────────┐
# │ datetime            ┆ symbol │
# │ ---                 ┆ ---    │
# │ datetime[ns]        ┆ str    │
# ╞═════════════════════╪════════╡
# │ 2009-08-06 00:00:00 ┆ AVGO   │
# │ 2009-08-07 00:00:00 ┆ AVGO   │
# │ 2009-08-10 00:00:00 ┆ AVGO   │
# │ 2009-08-11 00:00:00 ┆ AVGO   │
# │ 2009-08-12 00:00:00 ┆ AVGO   │
# │ …                   ┆ …      │
# │ 2025-01-17 00:00:00 ┆ TTE    │
# │ 2025-01-21 00:00:00 ┆ TTE    │
# │ 2025-01-22 00:00:00 ┆ TTE    │
# │ 2025-01-23 00:00:00 ┆ TTE    │
# │ 2025-01-24 00:00:00 ┆ TTE    │
# └─────────────────────┴────────┘

# %% [markdown]
# # 2. Macroindicators

# %% [markdown]
# ## 2.1 Indices

# %%
pl.read_parquet("../data/extracted/macro/^GSPC.parquet")
# Out:
# shape: (24_382, 10)
# ┌────────────┬────────────┬────────────┬───────────┬───┬────────┬──────────┬───────────┬───────────┐
# │ date       ┆ close      ┆ high       ┆ low       ┆ … ┆ symbol ┆ currency ┆ country   ┆ region    │
# │ ---        ┆ ---        ┆ ---        ┆ ---       ┆   ┆ ---    ┆ ---      ┆ ---       ┆ ---       │
# │ datetime[n ┆ f64        ┆ f64        ┆ f64       ┆   ┆ str    ┆ str      ┆ str       ┆ str       │
# │ s]         ┆            ┆            ┆           ┆   ┆        ┆          ┆           ┆           │
# ╞════════════╪════════════╪════════════╪═══════════╪═══╪════════╪══════════╪═══════════╪═══════════╡
# │ 1927-12-30 ┆ 17.66      ┆ 17.66      ┆ 17.66     ┆ … ┆ ^GSPC  ┆ USD      ┆ United    ┆ US_AMERIC │
# │ 00:00:00   ┆            ┆            ┆           ┆   ┆        ┆          ┆ States    ┆ A         │
# │ 1928-01-03 ┆ 17.76      ┆ 17.76      ┆ 17.76     ┆ … ┆ ^GSPC  ┆ USD      ┆ United    ┆ US_AMERIC │
# │ 00:00:00   ┆            ┆            ┆           ┆   ┆        ┆          ┆ States    ┆ A         │
# │ 1928-01-04 ┆ 17.719999  ┆ 17.719999  ┆ 17.719999 ┆ … ┆ ^GSPC  ┆ USD      ┆ United    ┆ US_AMERIC │
# │ 00:00:00   ┆            ┆            ┆           ┆   ┆        ┆          ┆ States    ┆ A         │
# │ 1928-01-05 ┆ 17.549999  ┆ 17.549999  ┆ 17.549999 ┆ … ┆ ^GSPC  ┆ USD      ┆ United    ┆ US_AMERIC │
# │ 00:00:00   ┆            ┆            ┆           ┆   ┆        ┆          ┆ States    ┆ A         │
# │ 1928-01-06 ┆ 17.66      ┆ 17.66      ┆ 17.66     ┆ … ┆ ^GSPC  ┆ USD      ┆ United    ┆ US_AMERIC │
# │ 00:00:00   ┆            ┆            ┆           ┆   ┆        ┆          ┆ States    ┆ A         │
# │ …          ┆ …          ┆ …          ┆ …         ┆ … ┆ …      ┆ …        ┆ …         ┆ …         │
# │ 2025-01-17 ┆ 5996.66015 ┆ 6014.95996 ┆ 5978.4399 ┆ … ┆ ^GSPC  ┆ USD      ┆ United    ┆ US_AMERIC │
# │ 00:00:00   ┆ 6          ┆ 1          ┆ 41        ┆   ┆        ┆          ┆ States    ┆ A         │
# │ 2025-01-21 ┆ 6049.24023 ┆ 6051.50976 ┆ 6006.8798 ┆ … ┆ ^GSPC  ┆ USD      ┆ United    ┆ US_AMERIC │
# │ 00:00:00   ┆ 4          ┆ 6          ┆ 83        ┆   ┆        ┆          ┆ States    ┆ A         │
# │ 2025-01-22 ┆ 6086.37011 ┆ 6100.81005 ┆ 6076.1298 ┆ … ┆ ^GSPC  ┆ USD      ┆ United    ┆ US_AMERIC │
# │ 00:00:00   ┆ 7          ┆ 9          ┆ 83        ┆   ┆        ┆          ┆ States    ┆ A         │
# │ 2025-01-23 ┆ 6118.70996 ┆ 6118.72998 ┆ 6074.6699 ┆ … ┆ ^GSPC  ┆ USD      ┆ United    ┆ US_AMERIC │
# │ 00:00:00   ┆ 1          ┆            ┆ 22        ┆   ┆        ┆          ┆ States    ┆ A         │
# │ 2025-01-24 ┆ 6101.24023 ┆ 6128.18017 ┆ 6088.7402 ┆ … ┆ ^GSPC  ┆ USD      ┆ United    ┆ US_AMERIC │
# │ 00:00:00   ┆ 4          ┆ 6          ┆ 34        ┆   ┆        ┆          ┆ States    ┆ A         │
# └────────────┴────────────┴────────────┴───────────┴───┴────────┴──────────┴───────────┴───────────┘

# %%
from functools import partial

indices = ["^GSPC","^DJI","^GDAXI","EPI"]

prefixed_growth = partial(ticker_extender.compute_daily_index_features,prefix=f"{indices[0]}_")
merged_indices = ticker_extender.read_transform_save(prefixed_growth,f"../../data/extracted/macro/{indices[0]}.parquet")
for index in indices[1:]:
    prefixed_growth = partial(ticker_extender.compute_daily_index_features,prefix=f"{index}_")
    index_df = ticker_extender.read_transform_save(prefixed_growth,f"../../data/extracted/macro/{index}.parquet")
    merged_indices = merged_indices.join(index_df,how="full",on="datetime")
    merged_indices = merged_indices.with_columns(pl.col("datetime")
                                                 .fill_null(pl.col("datetime_right"))) \
                                    .sort(by="datetime") \
                                    .select(pl.exclude("datetime_right")) \
                                    .fill_null(strategy="forward") 


merged_indices
# Out:
# shape: (24_612, 45)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ datetime  ┆ ^GSPC_gro ┆ ^GSPC_gro ┆ ^GSPC_gro ┆ … ┆ EPI_SMA22 ┆ EPI_30d_v ┆ EPI_high_ ┆ EPI_is_g │
# │ ---       ┆ wth_adj_1 ┆ wth_adj_3 ┆ wth_adj_7 ┆   ┆ ---       ┆ olatility ┆ minus_low ┆ rowing_m │
# │ datetime[ ┆ d         ┆ d         ┆ d         ┆   ┆ f64       ┆ ---       ┆ _relative ┆ oving_av │
# │ ns]       ┆ ---       ┆ ---       ┆ ---       ┆   ┆           ┆ f64       ┆ ---       ┆ erage    │
# │           ┆ f64       ┆ f64       ┆ f64       ┆   ┆           ┆           ┆ f64       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ i8       │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 1927-12-3 ┆ null      ┆ null      ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 0         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 1928-01-0 ┆ 1.005663  ┆ null      ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 3         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 1928-01-0 ┆ 0.997748  ┆ null      ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 4         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 1928-01-0 ┆ 0.990406  ┆ 0.993771  ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 5         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 1928-01-0 ┆ 1.006268  ┆ 0.994369  ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 6         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ 2025-01-2 ┆ 1.008768  ┆ 1.016694  ┆ 1.0365    ┆ … ┆ 45.112237 ┆ 16.36082  ┆ 0.003877  ┆ 0        │
# │ 1         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2025-01-2 ┆ 1.006138  ┆ 1.025101  ┆ 1.041668  ┆ … ┆ 44.951969 ┆ 15.617646 ┆ 0.005741  ┆ 0        │
# │ 2         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2025-01-2 ┆ 1.005313  ┆ 1.020353  ┆ 1.02837   ┆ … ┆ 44.853858 ┆ 15.40674  ┆ 0.004323  ┆ 0        │
# │ 3         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2025-01-2 ┆ 0.997145  ┆ 1.008596  ┆ 1.027605  ┆ … ┆ 44.730764 ┆ 15.169271 ┆ 0.003215  ┆ 0        │
# │ 4         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2025-01-2 ┆ 0.997145  ┆ 1.008596  ┆ 1.027605  ┆ … ┆ 44.730764 ┆ 15.169271 ┆ 0.003215  ┆ 0        │
# │ 7         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %% [markdown]
# # 2.2 GDP

# %%
file_handler = FileHandler()
gdppot = pd.read_csv("../data/extracted/macro/GDPPOT.csv",index_col=0)

gdppot['gdppot_us_yoy'] = gdppot["GDPPOT"].pct_change(4)
gdppot['gdppot_us_qoq'] = gdppot["GDPPOT"].pct_change(1)
gdppot.drop(columns="GDPPOT",inplace=True)

gdppot.index = pd.to_datetime(gdppot.index, utc=False, format="%Y-%m-%d")
gdppot
# Out:
#             gdppot_us_yoy  gdppot_us_qoq
# DATE
# 1955-01-01            NaN            NaN
# 1955-04-01            NaN       0.006516
# 1955-07-01            NaN       0.006366
# 1955-10-01            NaN       0.006565
# 1956-01-01       0.026246       0.006545
# ...                   ...            ...
# 2024-01-01       0.020357       0.005102
# 2024-04-01       0.020474       0.005143
# 2024-07-01       0.020675       0.005201
# 2024-10-01       0.020854       0.005247
# 2025-01-01       0.021063       0.005308
#
# [281 rows x 2 columns]

# %% [markdown]
# ## 2.3 CPI

# %%
cpilfesl = pd.read_csv("../data/extracted/macro/CPILFESL.csv",index_col=0)
cpilfesl.index = pd.to_datetime(cpilfesl.index, utc=False, format="%Y-%m-%d")

# information in current month is actually lagging from previous
cpilfesl.index = cpilfesl.index + pd.DateOffset(months=1)

cpilfesl['cpi_core_yoy_prev_month'] = cpilfesl["CPILFESL"].pct_change(12)
cpilfesl['cpi_core_mom_prev_month'] = cpilfesl["CPILFESL"].pct_change(1)

# cpilfesl.drop(columns="CPILFESL",inplace=True)
# cpilfesl.index = pd.to_datetime(cpilfesl.index, utc=False, format="%Y-%m-%d")
cpilfesl.tail(3)
# Out:
#             CPILFESL  cpi_core_yoy_prev_month  cpi_core_mom_prev_month
# DATE
# 2024-11-01   321.666                 0.033000                 0.002803
# 2024-12-01   322.657                 0.033002                 0.003081
# 2025-01-01   323.383                 0.032483                 0.002250

# %% [markdown]
# ## 2.4 FEDFUNDS

# %%
fedfunds = pd.read_csv("../data/extracted/macro/FEDFUNDS.csv",index_col=0)
fedfunds.index = pd.to_datetime(fedfunds.index, utc=False, format="%Y-%m-%d")

# information in current month is actually lagging from previous
fedfunds.index = fedfunds.index + pd.DateOffset(months=1)
fedfunds.columns = ["FEDFUNDS_prev_month"]

fedfunds
# Out:
#             FEDFUNDS_prev_month
# DATE
# 1955-02-01                 1.39
# 1955-03-01                 1.29
# 1955-04-01                 1.35
# 1955-05-01                 1.43
# 1955-06-01                 1.43
# ...                         ...
# 2024-09-01                 5.33
# 2024-10-01                 5.13
# 2024-11-01                 4.83
# 2024-12-01                 4.64
# 2025-01-01                 4.48
#
# [840 rows x 1 columns]

# %% [markdown]
# ## 2.5 Credit Risk - Euro AAA Bonds (Eurozone)

# %%
euro_yield_df = pd.read_csv("../data/extracted/macro/eurostat_euro_yield.csv", index_col=0)

# information in current day is actually lagging 2 days
euro_yield_df = ticker_extender.transform_euro_yield_df(euro_yield_df)


euro_yield_df
# Out:
# /home/miguel/data_science/algorithmic_trading/notebooks/../src/support/data_transformation.py:708: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   eurostat_euro_yield_df = pd.concat([eurostat_euro_yield_df,pd.DataFrame(columns=eurostat_euro_yield_df.columns, index=new_index)],axis=0).shift(2)
#                            eur_yld_Y1_prev_2d  eur_yld_Y10_prev_2d  \
# 2004-09-08 00:00:00+00:00             2.29884              4.20922
# 2004-09-09 00:00:00+00:00             2.32889              4.20963
# 2004-09-10 00:00:00+00:00             2.34667              4.22842
# 2004-09-13 00:00:00+00:00             2.30899              4.16187
# 2004-09-14 00:00:00+00:00             2.27157              4.12098
# ...                                       ...                  ...
# 2025-01-13 00:00:00+00:00             2.33536              2.61630
# 2025-01-14 00:00:00+00:00             2.36144              2.65624
# 2025-01-15 00:00:00+00:00             2.37913              2.68203
# 2025-01-16 00:00:00+00:00             2.37854              2.71869
# 2025-01-17 00:00:00+00:00             2.33828              2.63028
#
#                            eur_yld_Y5_prev_2d
# 2004-09-08 00:00:00+00:00             3.45722
# 2004-09-09 00:00:00+00:00             3.47952
# 2004-09-10 00:00:00+00:00             3.50789
# 2004-09-13 00:00:00+00:00             3.43063
# 2004-09-14 00:00:00+00:00             3.37473
# ...                                       ...
# 2025-01-13 00:00:00+00:00             2.27237
# 2025-01-14 00:00:00+00:00             2.32642
# 2025-01-15 00:00:00+00:00             2.35564
# 2025-01-16 00:00:00+00:00             2.39536
# 2025-01-17 00:00:00+00:00             2.30341
#
# [5195 rows x 3 columns]

# %% [markdown]
# ## 2.6 Credit Risk - DGS (Deposit Guarantee Schemes, US)

# %%
dgs = file_handler.read_csv_file("../data/extracted/macro/DGS.csv")
dgs.columns = [col + "_prev_1d" for col in dgs.columns] # lagged 1d
dgs.index = dgs.index + pd.offsets.BusinessDay(1)
dgs
# Out:
#                            DGS1_prev_1d  DGS5_prev_1d  DGS10_prev_1d
# DATE
# 1962-01-03 00:00:00+00:00          3.22          3.88           4.06
# 1962-01-04 00:00:00+00:00          3.24          3.87           4.03
# 1962-01-05 00:00:00+00:00          3.24          3.86           3.99
# 1962-01-08 00:00:00+00:00          3.26          3.89           4.02
# 1962-01-09 00:00:00+00:00          3.31          3.91           4.03
# ...                                 ...           ...            ...
# 2025-01-13 00:00:00+00:00          4.25          4.59           4.77
# 2025-01-14 00:00:00+00:00          4.24          4.61           4.79
# 2025-01-15 00:00:00+00:00          4.22          4.59           4.78
# 2025-01-16 00:00:00+00:00          4.19          4.45           4.66
# 2025-01-17 00:00:00+00:00          4.18          4.39           4.61
#
# [16448 rows x 3 columns]

# %% [markdown]
# ## 2.7 Volatility - VIX (US)

# %%
vix = file_handler.read_csv_file("../data/extracted/macro/VIX.csv")
vix = vix[["Close"]]
vix.columns = ["VIX_close"]
vix
# Out:
#                            VIX_close
# Date
# 1990-01-02 00:00:00+00:00  17.240000
# 1990-01-03 00:00:00+00:00  18.190001
# 1990-01-04 00:00:00+00:00  19.219999
# 1990-01-05 00:00:00+00:00  20.110001
# 1990-01-08 00:00:00+00:00  20.260000
# ...                              ...
# 2025-01-14 00:00:00+00:00  18.709999
# 2025-01-15 00:00:00+00:00  16.120001
# 2025-01-16 00:00:00+00:00  16.600000
# 2025-01-17 00:00:00+00:00  15.970000
# 2025-01-20 00:00:00+00:00  15.810000
#
# [8829 rows x 1 columns]

# %% [markdown]
# ## 2.8 Commodities - GOLD

# %%
prefixed_growth_gold = partial(ticker_extender.calculate_growth_features,prefix=f"gold_")
gold = ticker_extender.read_transform_save(prefixed_growth_gold,f"../data/extracted/macro/GOLD.csv")
gold
# Out:
#                            gold_growth_adj_1d  gold_growth_adj_3d  \
# Date
# 2000-08-30 00:00:00+00:00                 NaN                 NaN
# 2000-08-31 00:00:00+00:00            1.016064                 NaN
# 2000-09-01 00:00:00+00:00            0.995329                 NaN
# 2000-09-05 00:00:00+00:00            0.995668            1.006937
# 2000-09-06 00:00:00+00:00            0.994199            0.985268
# ...                                       ...                 ...
# 2025-01-10 00:00:00+00:00            1.009203            1.019498
# 2025-01-13 00:00:00+00:00            0.987078            1.003378
# 2025-01-14 00:00:00+00:00            1.001496            0.997653
# 2025-01-15 00:00:00+00:00            1.013072            1.001477
# 2025-01-20 00:00:00+00:00            1.004129            1.018777
#
#                            gold_growth_adj_7d  gold_growth_adj_30d  \
# Date
# 2000-08-30 00:00:00+00:00                 NaN                  NaN
# 2000-08-31 00:00:00+00:00                 NaN                  NaN
# 2000-09-01 00:00:00+00:00                 NaN                  NaN
# 2000-09-05 00:00:00+00:00                 NaN                  NaN
# 2000-09-06 00:00:00+00:00                 NaN                  NaN
# ...                                       ...                  ...
# 2025-01-10 00:00:00+00:00            1.024008             1.016361
# 2025-01-13 00:00:00+00:00            1.013304             0.991066
# 2025-01-14 00:00:00+00:00            1.007829             0.979406
# 2025-01-15 00:00:00+00:00            1.018015             1.009302
# 2025-01-20 00:00:00+00:00            1.014867             1.025489
#
#                            gold_growth_adj_90d  gold_growth_adj_365d
# Date
# 2000-08-30 00:00:00+00:00                  NaN                   NaN
# 2000-08-31 00:00:00+00:00                  NaN                   NaN
# 2000-09-01 00:00:00+00:00                  NaN                   NaN
# 2000-09-05 00:00:00+00:00                  NaN                   NaN
# 2000-09-06 00:00:00+00:00                  NaN                   NaN
# ...                                        ...                   ...
# 2025-01-10 00:00:00+00:00             1.024085              1.339714
# 2025-01-13 00:00:00+00:00             1.022371              1.327260
# 2025-01-14 00:00:00+00:00             1.027437              1.308203
# 2025-01-15 00:00:00+00:00             1.035068              1.338845
# 2025-01-20 00:00:00+00:00             1.024872              1.360082
#
# [6117 rows x 6 columns]

# %% [markdown]
# ## 2.9 Commodities - WTI Crude Oil (Futures and Spot)

# %%
prefixed_growth_crude = partial(ticker_extender.calculate_growth_features,prefix=f"crude_oil_")
crude_oil = ticker_extender.read_transform_save(prefixed_growth_crude,f"../data/extracted/macro/WTI_oil_futures.csv")
crude_oil
# Out:
#                            crude_oil_growth_adj_1d  crude_oil_growth_adj_3d  \
# Date
# 2000-08-23 00:00:00+00:00                      NaN                      NaN
# 2000-08-24 00:00:00+00:00                 0.986895                      NaN
# 2000-08-25 00:00:00+00:00                 1.013279                      NaN
# 2000-08-28 00:00:00+00:00                 1.025585                 1.025585
# 2000-08-29 00:00:00+00:00                 0.995437                 1.034461
# ...                                            ...                      ...
# 2025-01-10 00:00:00+00:00                 1.035850                 1.031246
# 2025-01-13 00:00:00+00:00                 1.029385                 1.075014
# 2025-01-14 00:00:00+00:00                 0.983253                 1.048431
# 2025-01-15 00:00:00+00:00                 1.032774                 1.045318
# 2025-01-20 00:00:00+00:00                 0.960020                 0.974879
#
#                            crude_oil_growth_adj_7d  crude_oil_growth_adj_30d  \
# Date
# 2000-08-23 00:00:00+00:00                      NaN                       NaN
# 2000-08-24 00:00:00+00:00                      NaN                       NaN
# 2000-08-25 00:00:00+00:00                      NaN                       NaN
# 2000-08-28 00:00:00+00:00                      NaN                       NaN
# 2000-08-29 00:00:00+00:00                      NaN                       NaN
# ...                                            ...                       ...
# 2025-01-10 00:00:00+00:00                 1.035289                  1.119936
# 2025-01-13 00:00:00+00:00                 1.071506                  1.149147
# 2025-01-14 00:00:00+00:00                 1.043771                  1.102575
# 2025-01-15 00:00:00+00:00                 1.091653                  1.143102
# 2025-01-20 00:00:00+00:00                 1.039502                  1.077851
#
#                            crude_oil_growth_adj_90d  crude_oil_growth_adj_365d
# Date
# 2000-08-23 00:00:00+00:00                       NaN                        NaN
# 2000-08-24 00:00:00+00:00                       NaN                        NaN
# 2000-08-25 00:00:00+00:00                       NaN                        NaN
# 2000-08-28 00:00:00+00:00                       NaN                        NaN
# 2000-08-29 00:00:00+00:00                       NaN                        NaN
# ...                                             ...                        ...
# 2025-01-10 00:00:00+00:00                  0.992611                   1.072860
# 2025-01-13 00:00:00+00:00                  1.071361                   1.094418
# 2025-01-14 00:00:00+00:00                  1.058165                   1.066318
# 2025-01-15 00:00:00+00:00                  1.055241                   1.105525
# 2025-01-20 00:00:00+00:00                  1.016940                   1.058986
#
# [6126 rows x 6 columns]

# %% [markdown]
# ## 2.10 Commodities - Brent Oil (Futures and Spot)

# %%
prefixed_growth_brent = partial(ticker_extender.calculate_growth_features,prefix=f"brent_oil_")
brent_oil = ticker_extender.read_transform_save(prefixed_growth_brent,f"../data/extracted/macro/Brent_oil_futures.csv")
brent_oil
# Out:
#                            brent_oil_growth_adj_1d  brent_oil_growth_adj_3d  \
# Date
# 2007-07-30 00:00:00+00:00                      NaN                      NaN
# 2007-07-31 00:00:00+00:00                 1.017296                      NaN
# 2007-08-01 00:00:00+00:00                 0.977936                      NaN
# 2007-08-02 00:00:00+00:00                 1.005441                 1.000264
# 2007-08-03 00:00:00+00:00                 0.986668                 0.970149
# ...                                            ...                      ...
# 2025-01-10 00:00:00+00:00                 1.036922                 1.035172
# 2025-01-13 00:00:00+00:00                 1.015672                 1.063682
# 2025-01-14 00:00:00+00:00                 0.986545                 1.039002
# 2025-01-15 00:00:00+00:00                 1.026401                 1.028460
# 2025-01-20 00:00:00+00:00                 0.963306                 0.975435
#
#                            brent_oil_growth_adj_7d  brent_oil_growth_adj_30d  \
# Date
# 2007-07-30 00:00:00+00:00                      NaN                       NaN
# 2007-07-31 00:00:00+00:00                      NaN                       NaN
# 2007-08-01 00:00:00+00:00                      NaN                       NaN
# 2007-08-02 00:00:00+00:00                      NaN                       NaN
# 2007-08-03 00:00:00+00:00                      NaN                       NaN
# ...                                            ...                       ...
# 2025-01-10 00:00:00+00:00                 1.042478                  1.105628
# 2025-01-13 00:00:00+00:00                 1.061730                  1.122178
# 2025-01-14 00:00:00+00:00                 1.037248                  1.087051
# 2025-01-15 00:00:00+00:00                 1.077075                  1.117423
# 2025-01-20 00:00:00+00:00                 1.027301                  1.060814
#
#                            brent_oil_growth_adj_90d  brent_oil_growth_adj_365d
# Date
# 2007-07-30 00:00:00+00:00                       NaN                        NaN
# 2007-07-31 00:00:00+00:00                       NaN                        NaN
# 2007-08-01 00:00:00+00:00                       NaN                        NaN
# 2007-08-02 00:00:00+00:00                       NaN                        NaN
# 2007-08-03 00:00:00+00:00                       NaN                        NaN
# ...                                             ...                        ...
# 2025-01-10 00:00:00+00:00                  0.985543                   1.038542
# 2025-01-13 00:00:00+00:00                  1.049624                   1.046506
# 2025-01-14 00:00:00+00:00                  1.043614                   1.020820
# 2025-01-15 00:00:00+00:00                  1.033123                   1.047771
# 2025-01-20 00:00:00+00:00                  0.999747                   1.014638
#
# [4344 rows x 6 columns]

# %% [markdown]
# ## 2.11 Cryptocurrency - BTC-USD

# %% [markdown]
# Non coincidental days from stocks market to BTC, as stocks are the goal, exclude those days of data from BTC.

# %%
prefixed_growth_btc = partial(ticker_extender.calculate_growth_features,prefix=f"BTC_")
BTC_usd = ticker_extender.read_transform_save(prefixed_growth_btc,f"../data/extracted/macro/BTC_usd.csv")
BTC_usd
# Out:
#                            BTC_growth_adj_1d  BTC_growth_adj_3d  \
# Date
# 2014-09-17 00:00:00+00:00                NaN                NaN
# 2014-09-18 00:00:00+00:00           0.928074                NaN
# 2014-09-19 00:00:00+00:00           0.930157                NaN
# 2014-09-20 00:00:00+00:00           1.035735           0.894104
# 2014-09-21 00:00:00+00:00           0.975341           0.939640
# ...                                      ...                ...
# 2025-01-16 00:00:00+00:00           0.992562           1.055444
# 2025-01-17 00:00:00+00:00           1.047166           1.082126
# 2025-01-18 00:00:00+00:00           0.999483           1.038840
# 2025-01-19 00:00:00+00:00           0.968216           1.013360
# 2025-01-20 00:00:00+00:00           1.034463           1.001067
#
#                            BTC_growth_adj_7d  BTC_growth_adj_30d  \
# Date
# 2014-09-17 00:00:00+00:00                NaN                 NaN
# 2014-09-18 00:00:00+00:00                NaN                 NaN
# 2014-09-19 00:00:00+00:00                NaN                 NaN
# 2014-09-20 00:00:00+00:00                NaN                 NaN
# 2014-09-21 00:00:00+00:00                NaN                 NaN
# ...                                      ...                 ...
# 2025-01-16 00:00:00+00:00           1.054885            1.004609
# 2025-01-17 00:00:00+00:00           1.105554            1.090469
# 2025-01-18 00:00:00+00:00           1.104654            1.108780
# 2025-01-19 00:00:00+00:00           1.047191            1.062268
# 2025-01-20 00:00:00+00:00           1.040485            1.118071
#
#                            BTC_growth_adj_90d  BTC_growth_adj_365d
# Date
# 2014-09-17 00:00:00+00:00                 NaN                  NaN
# 2014-09-18 00:00:00+00:00                 NaN                  NaN
# 2014-09-19 00:00:00+00:00                 NaN                  NaN
# 2014-09-20 00:00:00+00:00                 NaN                  NaN
# 2014-09-21 00:00:00+00:00                 NaN                  NaN
# ...                                       ...                  ...
# 2025-01-16 00:00:00+00:00            1.124636             1.582188
# 2025-01-17 00:00:00+00:00            1.187665             1.718330
# 2025-01-18 00:00:00+00:00            1.152608             1.717416
# 2025-01-19 00:00:00+00:00            1.158614             1.645114
# 2025-01-20 00:00:00+00:00            1.148326             1.662497
#
# [3779 rows x 6 columns]

# %% [markdown]
# # 3. Merging all together

# %%
stocks_indices_merged = pd.merge(merged_df_with_tech_ind,merged_indices, on="date", how="left")

# %%
stocks_indices_merged.tail()
# Out:
#              close        high         low        open     volume symbol  \
# 226949  349.140015  350.910004  344.369995  345.130005  2711200.0    ACN
# 226950  348.989990  352.519989  345.630005  351.209991  1825400.0    ACN
# 226951  349.730011  355.200012  349.059998  352.350006  2624000.0    ACN
# 226952  350.559998  353.250000  347.000000  349.109985  2025800.0    ACN
# 226953  352.589996  357.000000  351.910004  354.920013  4061300.0    ACN
#
#         country region                         industry      sector  ...  \
# 226949  ireland     EU  information-technology-services  technology  ...
# 226950  ireland     EU  information-technology-services  technology  ...
# 226951  ireland     EU  information-technology-services  technology  ...
# 226952  ireland     EU  information-technology-services  technology  ...
# 226953  ireland     EU  information-technology-services  technology  ...
#
#        ^GDAXI_growth_adj_7d  ^GDAXI_growth_adj_30d  ^GDAXI_growth_adj_90d  \
# 226949             0.995878               0.988902               1.052922
# 226950             0.996596               0.994443               1.061098
# 226951             1.012038               1.011241               1.079103
# 226952             1.016651               1.016047               1.072733
# 226953             1.034064               1.024718               1.088101
#
#         ^GDAXI_growth_adj_365d  EPI_growth_adj_1d EPI_growth_adj_3d  \
# 226949                1.211201           0.986102          0.960071
# 226950                1.223251           1.009935          0.971118
# 226951                1.252134           1.005948          1.001823
# 226952                1.246753           0.998635          1.014556
# 226953                1.262653           1.002733          1.007321
#
#        EPI_growth_adj_7d EPI_growth_adj_30d  EPI_growth_adj_90d  \
# 226949          0.944154           0.905175            0.901227
# 226950          0.970040           0.915505            0.893845
# 226951          0.975377           0.918265            0.895146
# 226952          0.975561           0.925300            0.897203
# 226953          1.003190           0.925494            0.896003
#
#         EPI_growth_adj_365d
# 226949             1.049180
# 226950             1.058069
# 226951             1.045433
# 226952             1.051487
# 226953             1.069948
#
# [5 rows x 176 columns]

# %%
stocks_to_gdppot = pd.merge(stocks_indices_merged, gdppot, how="left", left_on="quarter", right_index=True)

# %%
stocks_to_cpilfesl = pd.merge(stocks_to_gdppot, cpilfesl, how="left", left_on="month_dt", right_index=True)
stocks_to_cpilfesl.tail(3)
# Out:
#              close        high         low        open     volume symbol  \
# 226951  349.730011  355.200012  349.059998  352.350006  2624000.0    ACN
# 226952  350.559998  353.250000  347.000000  349.109985  2025800.0    ACN
# 226953  352.589996  357.000000  351.910004  354.920013  4061300.0    ACN
#
#         country region                         industry      sector  ...  \
# 226951  ireland     EU  information-technology-services  technology  ...
# 226952  ireland     EU  information-technology-services  technology  ...
# 226953  ireland     EU  information-technology-services  technology  ...
#
#        EPI_growth_adj_3d  EPI_growth_adj_7d  EPI_growth_adj_30d  \
# 226951          1.001823           0.975377            0.918265
# 226952          1.014556           0.975561            0.925300
# 226953          1.007321           1.003190            0.925494
#
#         EPI_growth_adj_90d  EPI_growth_adj_365d gdppot_us_yoy gdppot_us_qoq  \
# 226951            0.895146             1.045433      0.021063      0.005308
# 226952            0.897203             1.051487      0.021063      0.005308
# 226953            0.896003             1.069948      0.021063      0.005308
#
#        CPILFESL  cpi_core_yoy_prev_month  cpi_core_mom_prev_month
# 226951  323.383                 0.032483                  0.00225
# 226952  323.383                 0.032483                  0.00225
# 226953  323.383                 0.032483                  0.00225
#
# [3 rows x 181 columns]

# %%
stocks_to_fedfunds = pd.merge(stocks_to_cpilfesl, fedfunds, how="left", left_on="month_dt", right_index=True)
stocks_to_fedfunds.tail(3)
# Out:
#              close        high         low        open     volume symbol  \
# 226951  349.730011  355.200012  349.059998  352.350006  2624000.0    ACN
# 226952  350.559998  353.250000  347.000000  349.109985  2025800.0    ACN
# 226953  352.589996  357.000000  351.910004  354.920013  4061300.0    ACN
#
#         country region                         industry      sector  ...  \
# 226951  ireland     EU  information-technology-services  technology  ...
# 226952  ireland     EU  information-technology-services  technology  ...
# 226953  ireland     EU  information-technology-services  technology  ...
#
#        EPI_growth_adj_7d  EPI_growth_adj_30d  EPI_growth_adj_90d  \
# 226951          0.975377            0.918265            0.895146
# 226952          0.975561            0.925300            0.897203
# 226953          1.003190            0.925494            0.896003
#
#         EPI_growth_adj_365d  gdppot_us_yoy gdppot_us_qoq CPILFESL  \
# 226951             1.045433       0.021063      0.005308  323.383
# 226952             1.051487       0.021063      0.005308  323.383
# 226953             1.069948       0.021063      0.005308  323.383
#
#        cpi_core_yoy_prev_month  cpi_core_mom_prev_month  FEDFUNDS_prev_month
# 226951                0.032483                  0.00225                 4.48
# 226952                0.032483                  0.00225                 4.48
# 226953                0.032483                  0.00225                 4.48
#
# [3 rows x 182 columns]

# %%
stocks_to_euro_yld = pd.merge(stocks_to_fedfunds, euro_yield_df, how="left", left_on="date", right_index=True)
stocks_to_euro_yld.tail(3)
# Out:
#              close        high         low        open     volume symbol  \
# 226951  349.730011  355.200012  349.059998  352.350006  2624000.0    ACN
# 226952  350.559998  353.250000  347.000000  349.109985  2025800.0    ACN
# 226953  352.589996  357.000000  351.910004  354.920013  4061300.0    ACN
#
#         country region                         industry      sector  ...  \
# 226951  ireland     EU  information-technology-services  technology  ...
# 226952  ireland     EU  information-technology-services  technology  ...
# 226953  ireland     EU  information-technology-services  technology  ...
#
#        EPI_growth_adj_365d  gdppot_us_yoy  gdppot_us_qoq  CPILFESL  \
# 226951            1.045433       0.021063       0.005308   323.383
# 226952            1.051487       0.021063       0.005308   323.383
# 226953            1.069948       0.021063       0.005308   323.383
#
#         cpi_core_yoy_prev_month cpi_core_mom_prev_month FEDFUNDS_prev_month  \
# 226951                 0.032483                 0.00225                4.48
# 226952                 0.032483                 0.00225                4.48
# 226953                 0.032483                 0.00225                4.48
#
#        eur_yld_Y1_prev_2d  eur_yld_Y10_prev_2d  eur_yld_Y5_prev_2d
# 226951            2.37913              2.68203             2.35564
# 226952            2.37854              2.71869             2.39536
# 226953            2.33828              2.63028             2.30341
#
# [3 rows x 185 columns]

# %%
stocks_to_dgs = pd.merge(stocks_to_euro_yld, dgs, how="left", left_on="date", right_index=True)
stocks_to_dgs.tail(3)
# Out:
#              close        high         low        open     volume symbol  \
# 226951  349.730011  355.200012  349.059998  352.350006  2624000.0    ACN
# 226952  350.559998  353.250000  347.000000  349.109985  2025800.0    ACN
# 226953  352.589996  357.000000  351.910004  354.920013  4061300.0    ACN
#
#         country region                         industry      sector  ...  \
# 226951  ireland     EU  information-technology-services  technology  ...
# 226952  ireland     EU  information-technology-services  technology  ...
# 226953  ireland     EU  information-technology-services  technology  ...
#
#        CPILFESL  cpi_core_yoy_prev_month  cpi_core_mom_prev_month  \
# 226951  323.383                 0.032483                  0.00225
# 226952  323.383                 0.032483                  0.00225
# 226953  323.383                 0.032483                  0.00225
#
#         FEDFUNDS_prev_month  eur_yld_Y1_prev_2d eur_yld_Y10_prev_2d  \
# 226951                 4.48             2.37913             2.68203
# 226952                 4.48             2.37854             2.71869
# 226953                 4.48             2.33828             2.63028
#
#        eur_yld_Y5_prev_2d DGS1_prev_1d  DGS5_prev_1d  DGS10_prev_1d
# 226951            2.35564         4.22          4.59           4.78
# 226952            2.39536         4.19          4.45           4.66
# 226953            2.30341         4.18          4.39           4.61
#
# [3 rows x 188 columns]

# %%
stocks_to_vix = pd.merge(stocks_to_dgs, vix, how="left", left_on="date", right_index=True)
stocks_to_vix.tail(3)
# Out:
#              close        high         low        open     volume symbol  \
# 226951  349.730011  355.200012  349.059998  352.350006  2624000.0    ACN
# 226952  350.559998  353.250000  347.000000  349.109985  2025800.0    ACN
# 226953  352.589996  357.000000  351.910004  354.920013  4061300.0    ACN
#
#         country region                         industry      sector  ...  \
# 226951  ireland     EU  information-technology-services  technology  ...
# 226952  ireland     EU  information-technology-services  technology  ...
# 226953  ireland     EU  information-technology-services  technology  ...
#
#        cpi_core_yoy_prev_month  cpi_core_mom_prev_month  FEDFUNDS_prev_month  \
# 226951                0.032483                  0.00225                 4.48
# 226952                0.032483                  0.00225                 4.48
# 226953                0.032483                  0.00225                 4.48
#
#         eur_yld_Y1_prev_2d  eur_yld_Y10_prev_2d eur_yld_Y5_prev_2d  \
# 226951             2.37913              2.68203            2.35564
# 226952             2.37854              2.71869            2.39536
# 226953             2.33828              2.63028            2.30341
#
#        DGS1_prev_1d DGS5_prev_1d  DGS10_prev_1d  VIX_close
# 226951         4.22         4.59           4.78  16.120001
# 226952         4.19         4.45           4.66  16.600000
# 226953         4.18         4.39           4.61  15.970000
#
# [3 rows x 189 columns]

# %%
stocks_to_gold = pd.merge(stocks_to_vix, gold, how="left", left_on="date", right_index=True)
stocks_to_gold.tail(3)
# Out:
#              close        high         low        open     volume symbol  \
# 226951  349.730011  355.200012  349.059998  352.350006  2624000.0    ACN
# 226952  350.559998  353.250000  347.000000  349.109985  2025800.0    ACN
# 226953  352.589996  357.000000  351.910004  354.920013  4061300.0    ACN
#
#         country region                         industry      sector  ...  \
# 226951  ireland     EU  information-technology-services  technology  ...
# 226952  ireland     EU  information-technology-services  technology  ...
# 226953  ireland     EU  information-technology-services  technology  ...
#
#        DGS1_prev_1d  DGS5_prev_1d  DGS10_prev_1d  VIX_close  \
# 226951         4.22          4.59           4.78  16.120001
# 226952         4.19          4.45           4.66  16.600000
# 226953         4.18          4.39           4.61  15.970000
#
#         gold_growth_adj_1d gold_growth_adj_3d gold_growth_adj_7d  \
# 226951            1.013072           1.001477           1.018015
# 226952                 NaN                NaN                NaN
# 226953                 NaN                NaN                NaN
#
#        gold_growth_adj_30d  gold_growth_adj_90d  gold_growth_adj_365d
# 226951            1.009302             1.035068              1.338845
# 226952                 NaN                  NaN                   NaN
# 226953                 NaN                  NaN                   NaN
#
# [3 rows x 195 columns]

# %%
stocks_to_crude = pd.merge(stocks_to_gold, crude_oil, how="left", left_on="date", right_index=True)
stocks_to_crude.tail(3)
# Out:
#              close        high         low        open     volume symbol  \
# 226951  349.730011  355.200012  349.059998  352.350006  2624000.0    ACN
# 226952  350.559998  353.250000  347.000000  349.109985  2025800.0    ACN
# 226953  352.589996  357.000000  351.910004  354.920013  4061300.0    ACN
#
#         country region                         industry      sector  ...  \
# 226951  ireland     EU  information-technology-services  technology  ...
# 226952  ireland     EU  information-technology-services  technology  ...
# 226953  ireland     EU  information-technology-services  technology  ...
#
#        gold_growth_adj_7d  gold_growth_adj_30d  gold_growth_adj_90d  \
# 226951           1.018015             1.009302             1.035068
# 226952                NaN                  NaN                  NaN
# 226953                NaN                  NaN                  NaN
#
#         gold_growth_adj_365d  crude_oil_growth_adj_1d crude_oil_growth_adj_3d  \
# 226951              1.338845                 1.032774                1.045318
# 226952                   NaN                      NaN                     NaN
# 226953                   NaN                      NaN                     NaN
#
#        crude_oil_growth_adj_7d crude_oil_growth_adj_30d  \
# 226951                1.091653                 1.143102
# 226952                     NaN                      NaN
# 226953                     NaN                      NaN
#
#         crude_oil_growth_adj_90d  crude_oil_growth_adj_365d
# 226951                  1.055241                   1.105525
# 226952                       NaN                        NaN
# 226953                       NaN                        NaN
#
# [3 rows x 201 columns]

# %%
stocks_to_brent = pd.merge(stocks_to_crude, brent_oil, how="left", left_on="date", right_index=True)
stocks_to_brent.tail(3)
# Out:
#              close        high         low        open     volume symbol  \
# 226951  349.730011  355.200012  349.059998  352.350006  2624000.0    ACN
# 226952  350.559998  353.250000  347.000000  349.109985  2025800.0    ACN
# 226953  352.589996  357.000000  351.910004  354.920013  4061300.0    ACN
#
#         country region                         industry      sector  ...  \
# 226951  ireland     EU  information-technology-services  technology  ...
# 226952  ireland     EU  information-technology-services  technology  ...
# 226953  ireland     EU  information-technology-services  technology  ...
#
#        crude_oil_growth_adj_7d  crude_oil_growth_adj_30d  \
# 226951                1.091653                  1.143102
# 226952                     NaN                       NaN
# 226953                     NaN                       NaN
#
#         crude_oil_growth_adj_90d  crude_oil_growth_adj_365d  \
# 226951                  1.055241                   1.105525
# 226952                       NaN                        NaN
# 226953                       NaN                        NaN
#
#         brent_oil_growth_adj_1d brent_oil_growth_adj_3d  \
# 226951                 1.026401                 1.02846
# 226952                      NaN                     NaN
# 226953                      NaN                     NaN
#
#        brent_oil_growth_adj_7d brent_oil_growth_adj_30d  \
# 226951                1.077075                 1.117423
# 226952                     NaN                      NaN
# 226953                     NaN                      NaN
#
#         brent_oil_growth_adj_90d  brent_oil_growth_adj_365d
# 226951                  1.033123                   1.047771
# 226952                       NaN                        NaN
# 226953                       NaN                        NaN
#
# [3 rows x 207 columns]

# %%
stocks_to_btc = pd.merge(stocks_to_brent, BTC_usd, how="left", left_on="date", right_index=True)
stocks_to_btc.tail(3)
# Out:
#              close        high         low        open     volume symbol  \
# 226951  349.730011  355.200012  349.059998  352.350006  2624000.0    ACN
# 226952  350.559998  353.250000  347.000000  349.109985  2025800.0    ACN
# 226953  352.589996  357.000000  351.910004  354.920013  4061300.0    ACN
#
#         country region                         industry      sector  ...  \
# 226951  ireland     EU  information-technology-services  technology  ...
# 226952  ireland     EU  information-technology-services  technology  ...
# 226953  ireland     EU  information-technology-services  technology  ...
#
#        brent_oil_growth_adj_7d  brent_oil_growth_adj_30d  \
# 226951                1.077075                  1.117423
# 226952                     NaN                       NaN
# 226953                     NaN                       NaN
#
#         brent_oil_growth_adj_90d  brent_oil_growth_adj_365d  \
# 226951                  1.033123                   1.047771
# 226952                       NaN                        NaN
# 226953                       NaN                        NaN
#
#         BTC_growth_adj_1d BTC_growth_adj_3d BTC_growth_adj_7d  \
# 226951           1.041130          1.063670          1.061277
# 226952           0.992562          1.055444          1.054885
# 226953           1.047166          1.082126          1.105554
#
#        BTC_growth_adj_30d  BTC_growth_adj_90d  BTC_growth_adj_365d
# 226951           1.018529            1.248903             1.642554
# 226952           1.004609            1.124636             1.582188
# 226953           1.090469            1.187665             1.718330
#
# [3 rows x 213 columns]

# %% [markdown]
# # 4. Dataset save

# %%
stocks_to_btc.to_parquet("../data/transformed/dataset.parquet")
